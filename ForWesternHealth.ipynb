# %% [markdown]
# ## Let's predict WIES Value

# %%
# Importing the packages
import pickle
import pandas as pd
from sklearn import preprocessing

# %%
# Feature selection function
from sklearn.base import BaseEstimator, TransformerMixin

# custom function for RFI feature selection inside a pipeline
# here we use n_estimators=100
class RFIFeatureSelector(BaseEstimator, TransformerMixin):
    
    # class constructor 
    # make sure class attributes end with a "_"
    # per scikit-learn convention to avoid errors
    def __init__(self, n_features_=10):
        self.n_features_ = n_features_
        self.fs_indices_ = None

    # override the fit function
    def fit(self, X, y):
        from sklearn.ensemble import RandomForestRegressor
        from numpy import argsort
        model_rfi = RandomForestRegressor(n_estimators=80, max_depth=15)
        model_rfi.fit(X, y)
        self.fs_indices_ = argsort(model_rfi.feature_importances_)[::-1][0:self.n_features_] 
        return self 
    
    # override the transform function
    def transform(self, X, y=None):
        return X[:, self.fs_indices_]

# %%
# Load the provided model
loaded_model = pickle.load(open('PredictWIES.sav', 'rb'))

# %%
# Read Main data
DataAll = pd.read_csv('TheRelevant.csv', header = 0, sep=',', names = ['PatientID','IPEpisodeID','Gender Code',
                                                                     'Age On Admission','Birth Weight','ATSI Flag',
                                                                     'Admission Source Code','Admission Type Code',
                                                                     'Admission Specialty','Discharge Specialty',
                                                                     'Admission Ward Code','Discharge Ward Code',
                                                                     'Separation Method Code','DRG Code',
                                                                     'ICU LOS Hours','Total LOS Days','HITH Days',
                                                                     'LOS Type','WIES Value'])

DataAll.head()
# Out:
#    PatientID  IPEpisodeID Gender Code  Age On Admission  Birth Weight  \
# 0     973538      3320175           M                56           NaN
# 1    1198129      3327705           F                81           NaN
# 2     319442      3333120           M                82           NaN
# 3    1210448      3353681           M                88           NaN
# 4     387487      3355364           M                72           NaN
#
#   ATSI Flag Admission Source Code Admission Type Code Admission Specialty  \
# 0        No                     T                   P                HIHC
# 1        No                     S                   S                 GBS
# 2        No                     H                   C                  45
# 3        No                     H                   C                CRGS
# 4        No                     H                   C                IMSD
#
#   Discharge Specialty Admission Ward Code Discharge Ward Code  \
# 0                HIHC                 F2B               FHITH
# 1                 GBS               SHITH               SHITH
# 2                  26                 F2C               FHITH
# 3                UGIG                 F2E                 F3E
# 4                IMSD                 S2A                 S3E
#
#   Separation Method Code DRG Code  ICU LOS Hours  Total LOS Days  HITH Days  \
# 0                      H     K01C            NaN              34      67.94
# 1                      H     G70A            NaN              10      55.36
# 2                      H     K01C            NaN              18     102.62
# 3                      H     G02A         146.62              41       0.00
# 4                      S     F63A            NaN              59       0.00
#
#    LOS Type  WIES Value
# 0  Multiday      8.3579
# 1  Multiday      4.0218
# 2  Multiday      6.7687
# 3  Multiday      9.5665
# 4  Multiday      9.7236

# %%
# Read the data you want to test on. Rename Test.csv to your file name.
# Please make sure your test data has columns as specified here.
DataTest = pd.read_csv('Test.csv', header = 0, sep=',', names = ['PatientID','IPEpisodeID','Gender Code',
                                                                     'Age On Admission','Birth Weight','ATSI Flag',
                                                                     'Admission Source Code','Admission Type Code',
                                                                     'Admission Specialty','Discharge Specialty',
                                                                     'Admission Ward Code','Discharge Ward Code',
                                                                     'Separation Method Code','DRG Code',
                                                                     'ICU LOS Hours','Total LOS Days','HITH Days',
                                                                     'LOS Type'])
DataTest.head()
# Out:
#    PatientID  IPEpisodeID Gender Code  Age On Admission  Birth Weight  \
# 0     973538      3320175           M                56           NaN
# 1    1198129      3327705           F                81           NaN
# 2     319442      3333120           M                82           NaN
# 3    1210448      3353681           M                88           NaN
# 4     387487      3355364           M                72           NaN
#
#   ATSI Flag Admission Source Code Admission Type Code Admission Specialty  \
# 0        No                     T                   P                HIHC
# 1        No                     S                   S                 GBS
# 2        No                     H                   C                  45
# 3        No                     H                   C                CRGS
# 4        No                     H                   C                IMSD
#
#   Discharge Specialty Admission Ward Code Discharge Ward Code  \
# 0                HIHC                 F2B               FHITH
# 1                 GBS               SHITH               SHITH
# 2                  26                 F2C               FHITH
# 3                UGIG                 F2E                 F3E
# 4                IMSD                 S2A                 S3E
#
#   Separation Method Code DRG Code  ICU LOS Hours  Total LOS Days  HITH Days  \
# 0                      H     K01C            NaN              34      67.94
# 1                      H     G70A            NaN              10      55.36
# 2                      H     K01C            NaN              18     102.62
# 3                      H     G02A         146.62              41       0.00
# 4                      S     F63A            NaN              59       0.00
#
#    LOS Type
# 0  Multiday
# 1  Multiday
# 2  Multiday
# 3  Multiday
# 4  Multiday

# %%
DataAll = DataAll.drop(columns=['IPEpisodeID','PatientID','DRG Code','Birth Weight','ICU LOS Hours','WIES Value'])
DataTest = DataTest.drop(columns=['IPEpisodeID','PatientID','DRG Code','Birth Weight','ICU LOS Hours'])

# %%
# Fixing dimension
DataAll['dummycolumn']=1
DataTest['dummycolumn']=0
data = pd.concat([DataAll,DataTest])

# One hot encoding
categorical_cols = data.columns[data.dtypes==object].tolist()

for col in categorical_cols:
    n = len(data[col].unique())
    if (n == 2):
        data[col] = pd.get_dummies(data[col], drop_first=True)
        
data = pd.get_dummies(data)

# Seperating the data post dimension fixing
Original = data[data ["dummycolumn"] == 1]
TestData = data[data ["dummycolumn"] == 0]
TestData.drop(["dummycolumn"], axis=1, inplace=True)
TestData.head()

# Min-max scaling
Data_scaler = preprocessing.MinMaxScaler()

Data_scaler.fit(TestData)
Test = Data_scaler.fit_transform(TestData)
# Out:
#        Gender Code  Age On Admission ATSI Flag Admission Source Code  \
# 148320           M                78        No                     H
# 42149            M                55        No                     H
# 226709           F                28        No                     H
# 69287            F                20        No                     H
# 154613           M                37        No                     H
# 72506            M                36        No                     H
# 216022           F                 0        No                     H
# 133767           M                73        No                     H
# 19598            M                43        No                     H
# 142193           F                48        No                     H
#
#        Admission Type Code Admission Specialty Discharge Specialty  \
# 148320                   P                 DUA                 DUA
# 42149                    P                  34                  34
# 226709                   M               OBST2               OBST2
# 69287                    C                  44                  44
# 154613                   P                 DUA                 DUA
# 72506                    C                  44                  44
# 216022                   C                  12                 NBS
# 133767                   P                UGIG                UGIG
# 19598                    C                  44                  44
# 142193                   P                   9                   9
#
#        Admission Ward Code Discharge Ward Code Separation Method Code  \
# 148320                SDHM                SDHM                      H
# 42149                  S1E                 S1E                      H
# 226709               SWPCC                 S1B                      H
# 69287                 FEOU                FEOU                      H
# 154613                 WDU                 WDU                      H
# 72506                 FEOU                FEOU                      H
# 216022               SSCNI               SSCNI                      H
# 133767                FDPU                 F3E                      H
# 19598                 SEOU                SEOU                      H
# 142193               S1EMA               S1EMA                      H
#
#         Total LOS Days  HITH Days   LOS Type  dummycolumn
# 148320               1        0.0   Same day            1
# 42149                1        0.0   Same day            1
# 226709               2        0.0   Multiday            1
# 69287                1        0.0   Same day            1
# 154613               1        0.0   Same day            1
# 72506                1        0.0  Overnight            1
# 216022               2        0.0   Multiday            1
# 133767               1        0.0  Overnight            1
# 19598                1        0.0   Same day            1
# 142193               1        0.0   Same day            1

# %%
# Prediction
prediction = loaded_model.predict(Test).sum()

print("Predicted WIES Value -", prediction)
# Out:
# Predicted WIES Value - 1866.8596346889233

# %%
#Actual Sum - 1734.32
